# %% [markdown]
# ## Generated Sentences Expeirments

# %%
import data
import models
import experiments

# %%
# Create The Model API 
model_name = "codellama/CodeLlama-13b-Instruct-hf"
model_key = "EMPTY"
model_base_url = "http://0.0.0.0:8000/v1"
model_temp = 0.0
model_top_p = 0.95
model_max_tokens = 100

llama2_model = models.Model(model_name,model_key,model_base_url,model_temp, model_top_p, model_max_tokens)

# %% [markdown]
# #### Exp 2.1 & 2.2

# %%
experiments.exp_gen_sentences_ferretti('ferretti_instrument.csv','Instrument', llama2_model ,model_name)
# Out:
# conversation [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: serve plate
# Generate five semantically coherent sentences with the predicate 'serve', argument 'plate', and the role of Instrument. Reply only with a valid JSON object containing the key 'Sentences' and a value that is a list of  five semantically coherent sentences, each with the given predicate, argument, and role in the following the structure {'Sentences': [String]}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_generate_sentence   {
# "Sentences": [
# "The waiter served the food on the plate.",
# "The chef served the soup in the bowl.",
# "The baker served the cake on the plate.",
# "The chef served the salad in the bowl.",
# "The waiter served the drink in the glass."
# ]
# }
# Is the given sentence 'The waiter served the food on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "Yes"
# }
# Yes
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the food on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
#
#
#
# Given the following sentence, 'The waiter served the food on the plate.', for the predicate 'serve', how much does the argument 'plate' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', following the structure {'Fit score': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the food on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the food on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence 0.75
# Given the following sentence 'The waiter served the food on the plate.', for the predicate 'serve', how much does the argument 'plate' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is a float number from 0 to 1, following the structure {'Fit score': Float}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the food on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": 0.75
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the food on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence 0.75
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The chef served the soup in the bowl.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "No"
# }
# No
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the soup in the bowl.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'No'}]
#
#
#
# categorical from prev ['serve', 'plate', '5.9', '0.75']
# numerical from prev ['serve', 'plate', '5.9', '0.5']
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The baker served the cake on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "Yes"
# }
# Yes
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The baker served the cake on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
#
#
#
# Given the following sentence, 'The baker served the cake on the plate.', for the predicate 'serve', how much does the argument 'plate' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', following the structure {'Fit score': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The baker served the cake on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The baker served the cake on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence 0.75
# Given the following sentence 'The baker served the cake on the plate.', for the predicate 'serve', how much does the argument 'plate' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is a float number from 0 to 1, following the structure {'Fit score': Float}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The baker served the cake on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The baker served the cake on the plate.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence 0.8
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The chef served the salad in the bowl.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "No"
# }
# No
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the salad in the bowl.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'No'}]
#
#
#
# categorical from prev ['serve', 'plate', '5.9', '0.75']
# numerical from prev ['serve', 'plate', '5.9', '0.5']
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The waiter served the drink in the glass.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "No"
# }
# No
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the drink in the glass.' semantically coherent and containing the given predicate  'serve' and the argument 'plate' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'No'}]
#
#
#
# categorical from prev ['serve', 'plate', '5.9', '0.75']
# numerical from prev ['serve', 'plate', '5.9', '0.5']
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# ['serve', 'plate', 'The waiter served the food on the plate.', 0.75, '', 0.5, 'The baker served the cake on the plate.', 0.8, '', 0.5, '', 0.5, '5.9', 0.61]
# ['serve', 'plate', 'The waiter served the food on the plate.', 0.75, '', 0.75, 'The baker served the cake on the plate.', 0.75, '', 0.75, '', 0.75, '5.9', 0.75]
# conversation [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: serve tray
# Generate five semantically coherent sentences with the predicate 'serve', argument 'tray', and the role of Instrument. Reply only with a valid JSON object containing the key 'Sentences' and a value that is a list of  five semantically coherent sentences, each with the given predicate, argument, and role in the following the structure {'Sentences': [String]}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_generate_sentence   {
# "Sentences": [
# "The waiter served the tray of food on the table.",
# "The chef served the tray of ingredients to the cook.",
# "The server served the tray of drinks to the customer.",
# "The waiter served the tray of desserts to the guests.",
# "The chef served the tray of appetizers to the diners."
# ]
# }
# Is the given sentence 'The waiter served the tray of food on the table.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "Yes"
# }
# Yes
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the tray of food on the table.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
#
#
#
# Given the following sentence, 'The waiter served the tray of food on the table.', for the predicate 'serve', how much does the argument 'tray' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', following the structure {'Fit score': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the tray of food on the table.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the tray of food on the table.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence 0.75
# Given the following sentence 'The waiter served the tray of food on the table.', for the predicate 'serve', how much does the argument 'tray' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is a float number from 0 to 1, following the structure {'Fit score': Float}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the tray of food on the table.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the tray of food on the table.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence 0.8
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The chef served the tray of ingredients to the cook.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "Yes"
# }
# Yes
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the tray of ingredients to the cook.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
#
#
#
# Given the following sentence, 'The chef served the tray of ingredients to the cook.', for the predicate 'serve', how much does the argument 'tray' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', following the structure {'Fit score': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the tray of ingredients to the cook.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the tray of ingredients to the cook.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence 0.75
# Given the following sentence 'The chef served the tray of ingredients to the cook.', for the predicate 'serve', how much does the argument 'tray' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is a float number from 0 to 1, following the structure {'Fit score': Float}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the tray of ingredients to the cook.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": 0.75
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the tray of ingredients to the cook.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence 0.75
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The server served the tray of drinks to the customer.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "Yes"
# }
# Yes
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The server served the tray of drinks to the customer.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
#
#
#
# Given the following sentence, 'The server served the tray of drinks to the customer.', for the predicate 'serve', how much does the argument 'tray' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', following the structure {'Fit score': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The server served the tray of drinks to the customer.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The server served the tray of drinks to the customer.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence 0.75
# Given the following sentence 'The server served the tray of drinks to the customer.', for the predicate 'serve', how much does the argument 'tray' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is a float number from 0 to 1, following the structure {'Fit score': Float}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The server served the tray of drinks to the customer.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": 0.75
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The server served the tray of drinks to the customer.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence 0.75
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The waiter served the tray of desserts to the guests.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "Yes"
# }
# Yes
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the tray of desserts to the guests.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
#
#
#
# Given the following sentence, 'The waiter served the tray of desserts to the guests.', for the predicate 'serve', how much does the argument 'tray' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', following the structure {'Fit score': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the tray of desserts to the guests.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the tray of desserts to the guests.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence 0.75
# Given the following sentence 'The waiter served the tray of desserts to the guests.', for the predicate 'serve', how much does the argument 'tray' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is a float number from 0 to 1, following the structure {'Fit score': Float}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the tray of desserts to the guests.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": 0.75
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the tray of desserts to the guests.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence 0.75
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The chef served the tray of appetizers to the diners.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "Yes"
# }
# Yes
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the tray of appetizers to the diners.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
#
#
#
# Given the following sentence, 'The chef served the tray of appetizers to the diners.', for the predicate 'serve', how much does the argument 'tray' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', following the structure {'Fit score': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the tray of appetizers to the diners.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the tray of appetizers to the diners.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence 0.75
# Given the following sentence 'The chef served the tray of appetizers to the diners.', for the predicate 'serve', how much does the argument 'tray' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is a float number from 0 to 1, following the structure {'Fit score': Float}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the tray of appetizers to the diners.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": 0.75
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the tray of appetizers to the diners.' semantically coherent and containing the given predicate  'serve' and the argument 'tray' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence 0.75
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# ['serve', 'tray', 'The waiter served the tray of food on the table.', 0.8, 'The chef served the tray of ingredients to the cook.', 0.75, 'The server served the tray of drinks to the customer.', 0.75, 'The waiter served the tray of desserts to the guests.', 0.75, 'The chef served the tray of appetizers to the diners.', 0.75, '6.5', 0.76]
# ['serve', 'tray', 'The waiter served the tray of food on the table.', 0.75, 'The chef served the tray of ingredients to the cook.', 0.75, 'The server served the tray of drinks to the customer.', 0.75, 'The waiter served the tray of desserts to the guests.', 0.75, 'The chef served the tray of appetizers to the diners.', 0.75, '6.5', 0.75]
# conversation [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: serve glass
# ...
# response_check_semantic   {
# "Is Fit": "No"
# }
# No
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The waiter served the drinks in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'No'}]
#
#
#
# categorical from prev ['serve', 'bucket', '1.4', '0.75']
# numerical from prev ['serve', 'bucket', '1.4', '0.5']
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The chef served the food in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "No"
# }
# No
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The chef served the food in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'No'}]
#
#
#
# categorical from prev ['serve', 'bucket', '1.4', '0.75']
# numerical from prev ['serve', 'bucket', '1.4', '0.5']
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The delivery driver served the package in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "No"
# }
# No
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The delivery driver served the package in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'No'}]
#
#
#
# categorical from prev ['serve', 'bucket', '1.4', '0.75']
# numerical from prev ['serve', 'bucket', '1.4', '0.5']
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The mechanic served the oil in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "Yes"
# }
# Yes
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The mechanic served the oil in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
#
#
#
# Given the following sentence, 'The mechanic served the oil in the bucket.', for the predicate 'serve', how much does the argument 'bucket' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', following the structure {'Fit score': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The mechanic served the oil in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The mechanic served the oil in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence 0.75
# Given the following sentence 'The mechanic served the oil in the bucket.', for the predicate 'serve', how much does the argument 'bucket' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is a float number from 0 to 1, following the structure {'Fit score': Float}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The mechanic served the oil in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The mechanic served the oil in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence 0.8
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# Is the given sentence 'The gardener served the water in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_check_semantic   {
# "Is Fit": "Yes"
# }
# Yes
#
#
#
#  new senetence  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The gardener served the water in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
#
#
#
# Given the following sentence, 'The gardener served the water in the bucket.', for the predicate 'serve', how much does the argument 'bucket' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', following the structure {'Fit score': String}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The gardener served the water in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The gardener served the water in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence 0.75
# Given the following sentence 'The gardener served the water in the bucket.', for the predicate 'serve', how much does the argument 'bucket' fit the role of Instrument? Reply only with a valid JSON object containing the key 'Fit score' and a value that is a float number from 0 to 1, following the structure {'Fit score': Float}. Avoid adding any text outside this JSON object.
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The gardener served the water in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': "Is the given sentence 'The gardener served the water in the bucket.' semantically coherent and containing the given predicate  'serve' and the argument 'bucket' in the role of Instrument? Reply only with a valid JSON object containing the key 'Is Fit' and the value 'Yes' or 'No' in the following structure {'Is Fit': String}. Avoid adding any text outside this JSON object."}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence 0.8
#  after poping  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
#
#
#  *****************
# ['serve', 'bucket', '', 0.5, '', 0.5, '', 0.5, 'The mechanic served the oil in the bucket.', 0.8, 'The gardener served the water in the bucket.', 0.8, '1.4', 0.62]
# ['serve', 'bucket', '', 0.75, '', 0.75, '', 0.75, 'The mechanic served the oil in the bucket.', 0.75, 'The gardener served the water in the bucket.', 0.75, '1.4', 0.75]

# %% [markdown]
# #### Exp 3.1.1 & 3.1.2

# %%
experiments.exp_lemma_tuple_reasoning_ferretti('ferretti_instrument.csv', 'Instrument', llama2_model ,model_name)

# %%
print(llama2_model.conversa)
