# %% [markdown]
# ## Lamma Tuple Expeirments

# %%
import data
import models
import experiments

# %%
# Create The Model API 
model_name = "codellama/CodeLlama-13b-Instruct-hf"
model_key = "EMPTY"
model_base_url = "http://0.0.0.0:8000/v1"
model_temp = 0.0
model_top_p = 0.95
model_max_tokens = 100

llama2_model = models.Model(model_name,model_key,model_base_url,model_temp, model_top_p, model_max_tokens)

# %% [markdown]
# #### Exp 1.1 & 1.2

# %%
experiments.exp_lemma_tuple_ferretti('ferretti_instrument.csv','Instrument', llama2_model ,model_name)
# Out:
# the record is missing in either in E11 False or in False
# New Record: serve plate
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['serve', 'plate', '5.9']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: serve tray
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['serve', 'tray', '6.5']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: serve glass
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['serve', 'glass', '4.9']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: serve platter
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['serve', 'platter', '5.8']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: serve bucket
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['serve', 'bucket', '1.4']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sweep mop
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sweep', 'mop', '3.7']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sweep rag
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sweep', 'rag', '3.1']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sweep broom
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sweep', 'broom', '7']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 1.0
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sweep rake
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sweep', 'rake', '3']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sweep brush
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sweep', 'brush', '3.7']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sweep rock
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sweep', 'rock', '1']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: write pen
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['write', 'pen', '6.9']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: write keyboard
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['write', 'keyboard', '4.8']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: write thesaurus
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['write', 'thesaurus', '3.8']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: write stick
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['write', 'stick', '1.8']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: write pencil
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['write', 'pencil', '6.8']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: write desk
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['write', 'desk', '4.9']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: write wire
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['write', 'wire', '1']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: write sword
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['write', 'sword', '1']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: write box
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['write', 'box', '1']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: paint brush
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['paint', 'brush', '6.8']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: paint roller
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['paint', 'roller', '6.6']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: paint straw
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['paint', 'straw', '1.4']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: paint can
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['paint', 'can', '5.2']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: paint sponge
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['paint', 'sponge', '4.5']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: paint rag
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['paint', 'rag', '3.9']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: shoot gun
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['shoot', 'gun', '6.8']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: shoot straw
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['shoot', 'straw', '1.5']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: shoot rifle
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['shoot', 'rifle', '6.8']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: shoot cannon
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['shoot', 'cannon', '4.5']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: shoot pistol
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['shoot', 'pistol', '6.5']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: shoot tank
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['shoot', 'tank', '4']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: shoot arrow
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['shoot', 'arrow', '5']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: dust Kleenex
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['dust', 'Kleenex', '3.5']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: dust rag
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['dust', 'rag', '6.8']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: dust sock
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['dust', 'sock', '3.2']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: dust cloth
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['dust', 'cloth', '6.2']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: dust water
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['dust', 'water', '2.9']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.0
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: dust beer
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['dust', 'beer', '1.1']
# ...
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['lock', 'tape', '1.6']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: lock rope
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['lock', 'rope', '2.2']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: lock bar
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['lock', 'bar', '3.1']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: lock padlock
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['lock', 'padlock', '5.6']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: lock latch
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['lock', 'latch', '5.3']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sterilize water
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sterilize', 'water', '5.3']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sterilize heat
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sterilize', 'heat', '6.6']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sterilize air
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sterilize', 'air', '2.8']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sterilize alcohol
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sterilize', 'alcohol', '5.4']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sterilize pressure
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sterilize', 'pressure', '2.9']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sterilize chemical
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sterilize', 'chemical', '5.6']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sterilize salt
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sterilize', 'salt', '2.5']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# the record is missing in either in E11 False or in False
# New Record: sterilize butter
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# ['sterilize', 'butter', '1']
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_fit_score   {
# "Fit score": 0.5
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]

# %% [markdown]
# #### Exp 3.1.1 & 3.1.2

# %%
experiments.exp_lemma_tuple_reasoning_ferretti('ferretti_instrument.csv', 'Instrument', llama2_model ,model_name)
# Out:
# the record is missing in either in E11 False or in False
# New Record: serve plate
# #############reason_prompt:#################
#  Given the predicate 'serve', what properties should the Instrument role have? Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.
# After /n/n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}]
# response_reason   {
# "Response": "The Instrument role should have the properties of being a physical object that is used to perform the action of serving."
# }
# -----------
#
# #############reason_prompt:#################
#  Given  the predicate 'serve', and the argument 'plate', what relevant properties does the argument have? Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.
# After /n/n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}]
# response_reason   {
# "Response": "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."
# }
# -----------
#
# #############reason_prompt:#################
#  Given the above, how will the argument 'plate' fit the Instrument role for the predicate 'serve'? Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.
# After /n/n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}]
# response_reason   {
# "Response": "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."
# }
# -----------
#
# ['The Instrument role should have the properties of being a physical object that is used to perform the action of serving.', "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving.", "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."]
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}]
# response_fit_score   {
# "Fit score": "High"
# }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}]
# ['serve', 'plate', '5.9', 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.', "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving.", "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."]
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}]
# response_fit_score   {
# "Fit score": 0.8
# }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}]
# the record is missing in either in E11 False or in False
# New Record: serve tray
# #############reason_prompt:#################
#  Given the predicate 'serve', what properties should the Instrument role have? Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.
# After /n/n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}]
# response_reason   {
# "Response": "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving."
# }
# -----------
#
# #############reason_prompt:#################
#  Given  the predicate 'serve', and the argument 'tray', what relevant properties does the argument have? Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.
# After /n/n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'tray\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}]
# response_reason   { "Response": "The argument 'tray' has the properties of being a physical object that is used to perform the action of serving." }
# -----------
#
# #############reason_prompt:#################
#  Given the above, how will the argument 'tray' fit the Instrument role for the predicate 'serve'? Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.
# After /n/n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'tray\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'tray' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'tray\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}]
# response_reason   The argument 'tray' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving.
# -----------
#
# ["The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving.", "The argument 'tray' has the properties of being a physical object that is used to perform the action of serving.", "  The argument 'tray' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."]
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'tray\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'tray' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'tray\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "  The argument 'tray' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}]
# response_fit_score   { "Fit score": "High" }
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'tray\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'tray' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'tray\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "  The argument 'tray' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}]
# ['serve', 'tray', '6.5', "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving.", "The argument 'tray' has the properties of being a physical object that is used to perform the action of serving.", "  The argument 'tray' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."]
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'tray\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'tray' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'tray\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "  The argument 'tray' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}]
# response_fit_score   { "Fit score": 0.8 }
# conversation before: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'tray\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'tray' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'tray\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "  The argument 'tray' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}]
# the record is missing in either in E11 False or in False
# New Record: serve glass
# #############reason_prompt:#################
#  Given the predicate 'serve', what properties should the Instrument role have? Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.
# After /n/n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'tray\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'tray' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'tray\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "  The argument 'tray' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}]
# response_reason   { "Response": "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving." }
# -----------
#
# #############reason_prompt:#################
#  Given  the predicate 'serve', and the argument 'glass', what relevant properties does the argument have? Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.
# After /n/n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': 'The Instrument role should have the properties of being a physical object that is used to perform the action of serving.'}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'plate\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'plate\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'plate' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given  the predicate \'serve\', and the argument \'tray\', what relevant properties does the argument have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The argument 'tray' has the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the above, how will the argument \'tray\' fit the Instrument role for the predicate \'serve\'?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "  The argument 'tray' fits the Instrument role for the predicate 'serve' because it is a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should the Instrument role have?  Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.'}, {'role': 'assistant', 'content': "The Instrument role for the predicate 'serve' should have the properties of being a physical object that is used to perform the action of serving."}, {'role': 'user', 'content': 'Given  the predicate \'serve ...
# response_reason   { "Response": "The argument 'glass' has the properties of being a physical object that is used to perform the action of serving." }
# -----------
#
# #############reason_prompt:#################
#  Given the above, how will the argument 'glass' fit the Instrument role for the predicate 'serve'? Return the answer as a valid JSON object with the structure {"Response": String}. Avoid adding any text outside this JSON object. Do not include ```json in the response. Make sure that the answer length fits in the JSON object.
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 experiments.exp_lemma_tuple_reasoning_ferretti('ferretti_instrument.csv', 'Instrument', llama2_model ,model_name)
#
# File ~/new_design/experiments.py:122, in exp_lemma_tuple_reasoning_ferretti(filename, role_type, model, model_name)
#     118 result2 = [predicate, argument, actual_fit]
#     121 '''Reasoning'''
# --> 122 reasons_results = fit_scoring.reasoning(model,predicate, argument, roleType)
#     124 '''TRACKING'''
#     125 print(reasons_results)
#
# File ~/new_design/fit_scoring.py:98, in reasoning(model, predicate, argument, roleType)
#      95 print('After /n/n', model.conversation)
#      97 # Interact with model
# ---> 98 response_reason = model.chat_with_model()
#     100 '''TRACING'''
#     101 print('response_reason', response_reason , '\n-----------\n')
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/new_design/models.py:31, in Model.chat_with_model(self)
#      29 @retry(wait=wait_random_exponential(min=1, max=40), stop=stop_after_attempt(3))
#      30 def chat_with_model(self):
# ---> 31     completion = self.client.chat.completions.create(
#      32         model= self.model_name_,
#      33         messages= self.conversation,
#      34         temperature= self.temp,
#      35         top_p = self.top_p,
#      36         max_tokens = self.max_tokens
#      37     )
#      39     return completion.choices[0].message.content
#
# File /opt/conda/lib/python3.10/site-packages/openai/_utils/_utils.py:299, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297             msg = f"Missing required argument: {quote(missing[0])}"
#     298     raise TypeError(msg)
# --> 299 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/openai/resources/chat/completions.py:594, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     548 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     549 def create(
#     550     self,
#    (...)
#     592     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     593 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 594     return self._post(
#     595         "/chat/completions",
#     596         body=maybe_transform(
#     597             {
#     598                 "messages": messages,
#     599                 "model": model,
#     600                 "frequency_penalty": frequency_penalty,
#     601                 "function_call": function_call,
#     602                 "functions": functions,
#     603                 "logit_bias": logit_bias,
#     604                 "max_tokens": max_tokens,
#     605                 "n": n,
#     606                 "presence_penalty": presence_penalty,
#     607                 "response_format": response_format,
#     608                 "seed": seed,
#     609                 "stop": stop,
#     610                 "stream": stream,
#     611                 "temperature": temperature,
#     612                 "tool_choice": tool_choice,
#     613                 "tools": tools,
#     614                 "top_p": top_p,
#     615                 "user": user,
#     616             },
#     617             completion_create_params.CompletionCreateParams,
#     618         ),
#     619         options=make_request_options(
#     620             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     621         ),
#     622         cast_to=ChatCompletion,
#     623         stream=stream or False,
#     624         stream_cls=Stream[ChatCompletionChunk],
#     625     )
#
# File /opt/conda/lib/python3.10/site-packages/openai/_base_client.py:1055, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1041 def post(
#    1042     self,
#    1043     path: str,
#    (...)
#    1050     stream_cls: type[_StreamT] | None = None,
#    1051 ) -> ResponseT | _StreamT:
#    1052     opts = FinalRequestOptions.construct(
#    1053         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1054     )
# -> 1055     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/conda/lib/python3.10/site-packages/openai/_base_client.py:834, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     825 def request(
#     826     self,
#     827     cast_to: Type[ResponseT],
#    (...)
#     832     stream_cls: type[_StreamT] | None = None,
#     833 ) -> ResponseT | _StreamT:
# --> 834     return self._request(
#     835         cast_to=cast_to,
#     836         options=options,
#     837         stream=stream,
#     838         stream_cls=stream_cls,
#     839         remaining_retries=remaining_retries,
#     840     )
#
# File /opt/conda/lib/python3.10/site-packages/openai/_base_client.py:858, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     855 self._prepare_request(request)
#     857 try:
# --> 858     response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859     log.debug(
#     860         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     861     )
#     862     response.raise_for_status()
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#     997     raise RuntimeError(
#     998         "Attempted to send an async request with a sync Client instance."
#     999     )
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#    1006 response.request = request
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#     232 return Response(
#     233     status_code=resp.status,
#     234     headers=resp.headers,
#     235     stream=ResponseStream(resp.stream),
#     236     extensions=resp.extensions,
#     237 )
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
print(llama2_model.conversa)

# %% [markdown]
# ### with codeLlama2

# %% [markdown]
# #### Exp 1.1 & 1.2

# %% [markdown]
# #### Exp 3.1.1 & 3.1.2

# %%
import re
print('ff.csv'.split('.csv')[0])
# Out:
# ff
