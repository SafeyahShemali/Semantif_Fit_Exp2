# %% [markdown]
# ### Checking and analysis

# %%
import data

# %% [markdown]
# - For ferretti Instrument

# %%
data.result_checking('ferretti_instrument.csv','Result/lemma_tuple_categorical_ferretti_instrument_CodeLlama-13b-Instruct-hf.csv')

# %%
data.result_checking('ferretti_instrument.csv','Result/lemma_tuple_numerical_ferretti_instrument_CodeLlama-13b-Instruct-hf.csv')

# %% [markdown]
# - For ferretti Location

# %%
data.result_checking('ferretti_location.csv','Result/lemma_tuple_categorical_ferretti_location_CodeLlama-13b-Instruct-hf.csv')

# %%
data.result_checking('ferretti_location.csv','Result/lemma_tuple_numerical_ferretti_location_CodeLlama-13b-Instruct-hf.csv')

# %% [markdown]
# - For Pado

# %%
data.result_checking('pado_plausibility_pb.txt','Result/lemma_tuple_categorical_pado_plausibility_pb_CodeLlama-13b-Instruct-hf.csv')
# Out:
# 414
# advise banker ARG0 True
# advise banker ARG1 True
# advise biologist ARG0 True
# advise biologist ARG1 True
# advise business ARG0 True
# advise business ARG1 True
# advise client ARG0 True
# advise client ARG1 True
# advise customer ARG0 True
# advise customer ARG1 True
# advise designer-gardener ARG0 True
# advise designer-gardener ARG1 True
# advise doctor ARG0 True
# advise doctor ARG1 True
# advise expert ARG0 True
# advise expert ARG1 True
# advise hospital ARG0 True
# advise hospital ARG1 True
# advise investor ARG0 True
# advise investor ARG1 True
# advise official ARG0 True
# advise official ARG1 True
# advise planner ARG0 True
# advise planner ARG1 True
# ask charity ARG0 True
# ask charity ARG2 True
# ask congress ARG0 True
# ask congress ARG2 True
# ask court ARG0 True
# ask court ARG2 True
# ask department ARG0 True
# ask department ARG2 True
# ask doctor ARG0 True
# ask doctor ARG2 True
# ask firm ARG0 True
# ask firm ARG2 True
# ask official ARG0 True
# ask official ARG2 True
# ask police ARG0 True
# ask police ARG2 True
# ask prosecutor ARG0 True
# ask prosecutor ARG2 True
# ask state ARG0 True
# ask state ARG2 True
# ask union ARG0 True
# ask union ARG2 True
# caution bank ARG0 True
# caution bank ARG2 True
# caution developer ARG0 True
# caution developer ARG2 True
# caution friend ARG0 True
# caution friend ARG2 True
# caution judges ARG0 True
# caution judges ARG2 True
# caution lady ARG0 True
# caution lady ARG2 True
# caution leader ARG0 True
# caution leader ARG2 True
# caution police ARG0 True
# caution police ARG2 True
# caution professional ARG0 True
# caution professional ARG2 True
# caution rain ARG0 True
# caution rain ARG2 True
# caution trader ARG0 True
# caution trader ARG2 True
# caution user ARG0 True
# caution user ARG2 True
# caution woman ARG0 True
# caution woman ARG2 True
# confuse baby ARG0 True
# confuse baby ARG1 True
# confuse boatman ARG0 True
# confuse boatman ARG1 True
# confuse comment ARG0 True
# confuse comment ARG1 True
# confuse community ARG0 True
# confuse community ARG1 True
# confuse computer ARG0 True
# confuse computer ARG1 True
# confuse condition ARG0 True
# confuse condition ARG1 True
# confuse equipment ARG0 True
# confuse equipment ARG1 True
# confuse insistence ARG0 True
# confuse insistence ARG1 True
# confuse sense ARG0 True
# confuse sense ARG1 True
# confuse shareholder ARG0 True
# confuse shareholder ARG1 True
# confuse situation ARG0 True
# confuse situation ARG1 True
# confuse statement ARG0 True
# confuse statement ARG1 True
# eat apple ARG0 True
# eat apple ARG1 True
# eat cost ARG0 True
# eat cost ARG1 True
# eat debt ARG0 True
# eat debt ARG1 True
# eat egg ARG0 True
# eat egg ARG1 True
# eat group ARG0 True
# eat group ARG1 True
# eat husband ARG0 True
# eat husband ARG1 True
# eat local ARG0 True
# eat local ARG1 True
# eat lunch ARG0 True
# eat lunch ARG1 True
# eat meal ARG0 True
# eat meal ARG1 True
# eat people ARG0 True
# eat people ARG1 True
# eat pizza ARG0 True
# eat pizza ARG1 True
# eat villager ARG0 True
# eat villager ARG1 True
# eliminate act ARG0 True
# eliminate act ARG1 True
# eliminate barrier ARG0 True
# eliminate barrier ARG1 True
# eliminate club ARG0 True
# eliminate club ARG1 True
# eliminate intruder ARG0 True
# eliminate intruder ARG1 True
# eliminate job ARG0 True
# eliminate job ARG1 True
# eliminate law ARG0 True
# eliminate law ARG1 True
# eliminate need ARG0 True
# eliminate need ARG1 True
# eliminate policy ARG0 True
# eliminate policy ARG1 True
# eliminate provision ARG0 True
# eliminate provision ARG1 True
# eliminate therapy ARG0 True
# eliminate therapy ARG1 True
# embarrass board ARG0 True
# embarrass board ARG1 True
# embarrass book-keeping ARG0 True
# embarrass book-keeping ARG1 True
# embarrass conservative ARG0 True
# embarrass conservative ARG1 True
# embarrass executive ARG0 True
# embarrass executive ARG1 True
# embarrass government ARG0 True
# embarrass government ARG1 True
# embarrass importunity ARG0 True
# embarrass importunity ARG1 True
# embarrass information ARG0 True
# embarrass information ARG1 True
# embarrass intervener ARG0 True
# embarrass intervener ARG1 True
# embarrass lyric ARG0 True
# embarrass lyric ARG1 True
# embarrass official ARG0 True
# embarrass official ARG1 True
# embarrass revelation ARG0 True
# embarrass revelation ARG1 True
# embarrass treatment ARG0 True
# embarrass treatment ARG1 True
# encourage affiliate ARG0 True
# encourage affiliate ARG1 True
# encourage boy ARG0 True
# encourage boy ARG1 True
# encourage client ARG0 True
# encourage client ARG1 True
# encourage company ARG0 True
# encourage company ARG1 True
# encourage executive ARG0 True
# encourage executive ARG1 True
# encourage government ARG0 True
# encourage government ARG1 True
# encourage investor ARG0 True
# encourage investor ARG1 True
# encourage pupil ARG0 True
# encourage pupil ARG1 True
# encourage purpose ARG0 True
# encourage purpose ARG1 True
# encourage technician ARG0 True
# encourage technician ARG1 True
# encourage uncertainty ARG0 True
# encourage uncertainty ARG1 True
# encourage vicar ARG0 True
# encourage vicar ARG1 True
# hear appeal ARG0 True
# hear appeal ARG1 True
# hear board ARG0 True
# hear board ARG1 True
# hear case ARG0 True
# hear case ARG1 True
# hear committee ARG0 True
# hear committee ARG1 True
# hear court ARG0 True
# hear court ARG1 True
# hear ear ARG0 True
# hear ear ARG1 True
# hear girl ARG0 True
# hear girl ARG1 True
# hear knock ARG0 True
# hear knock ARG1 True
# hear man ARG0 True
# hear man ARG1 True
# hear moan ARG0 True
# hear moan ARG1 True
# hear sound ARG0 True
# hear sound ARG1 True
# hear voice ARG0 True
# hear voice ARG1 True
# hit baby ARG0 True
# hit baby ARG1 True
# hit ball ARG2 True
# hit ball ARG1 True
# hit brother ARG0 True
# hit brother ARG1 True
# hit creature ARG0 True
# hit creature ARG1 True
# hit earthquake ARG2 True
# hit earthquake ARG1 True
# hit man ARG0 True
# hit man ARG1 True
# hit market ARG2 True
# hit market ARG1 True
# hit mummy ARG0 True
# hit mummy ARG1 True
# hit opponent ARG0 True
# hit opponent ARG1 True
# hit player ARG0 True
# hit player ARG1 True
# hit quake ARG2 True
# hit quake ARG1 True
# hit stock ARG2 True
# hit stock ARG1 True
# increase amount ARG0 True
# increase amount ARG1 True
# increase authority ARG0 True
# increase authority ARG1 True
# increase bank ARG0 True
# increase bank ARG1 True
# increase company ARG0 True
# increase company ARG1 True
# increase industry ARG0 True
# increase industry ARG1 True
# increase model ARG0 True
# increase model ARG1 True
# increase move ARG0 True
# increase move ARG1 True
# increase number ARG0 True
# increase number ARG1 True
# increase rate ARG0 True
# increase rate ARG1 True
# increase revenue ARG0 True
# increase revenue ARG1 True
# increase sale ARG0 True
# increase sale ARG1 True
# inform administration ARG0 True
# inform administration ARG1 True
# inform center ARG0 True
# inform center ARG1 True
# inform committee ARG0 True
# inform committee ARG1 True
# inform employee ARG0 True
# inform employee ARG1 True
# inform foundation ARG0 True
# inform foundation ARG1 True
# inform network ARG0 True
# inform network ARG1 True
# inform police ARG0 True
# inform police ARG1 True
# inform public ARG0 True
# inform public ARG1 True
# inform reader ARG0 True
# inform reader ARG1 True
# inform secretary ARG0 True
# inform secretary ARG1 True
# inform system ARG0 True
# inform system ARG1 True
# kill antibody ARG0 True
# kill antibody ARG1 True
# kill cell ARG0 True
# kill cell ARG1 True
# kill girl ARG0 True
# kill girl ARG1 True
# kill group ARG0 True
# kill group ARG1 True
# kill house ARG0 True
# kill house ARG1 True
# kill item ARG0 True
# kill item ARG1 True
# kill lion ARG0 True
# kill lion ARG1 True
# kill man ARG0 True
# kill man ARG1 True
# kill mother ARG0 True
# kill mother ARG1 True
# kill people ARG0 True
# kill people ARG1 True
# kill rebel ARG0 True
# kill rebel ARG1 True
# kill shark ARG0 True
# kill shark ARG1 True
# promise administration ARG0 True
# promise administration ARG1 True
# promise company ARG0 True
# promise company ARG1 True
# promise customer ARG0 True
# promise customer ARG1 True
# promise foundation ARG0 True
# promise foundation ARG1 True
# promise fund ARG0 True
# promise fund ARG1 True
# promise government ARG0 True
# promise government ARG1 True
# promise parent ARG0 True
# promise parent ARG1 True
# promise plan ARG0 True
# promise plan ARG1 True
# promise state ARG0 True
# promise state ARG1 True
# promise station ARG0 True
# promise station ARG1 True
# promise sun-god ARG0 True
# promise sun-god ARG1 True
# raise bank ARG0 True
# raise bank ARG1 True
# raise congress ARG0 True
# raise congress ARG1 True
# raise country ARG0 True
# raise country ARG1 True
# raise dividend ARG0 True
# raise dividend ARG1 True
# raise firm ARG0 True
# raise firm ARG1 True
# raise government ARG0 True
# raise government ARG1 True
# raise price ARG0 True
# raise price ARG1 True
# raise question ARG0 True
# raise question ARG1 True
# raise rate ARG0 True
# raise rate ARG1 True
# raise stake ARG0 True
# raise stake ARG1 True
# resent contribution ARG0 True
# resent contribution ARG1 True
# resent cost ARG0 True
# resent cost ARG1 True
# resent firm ARG0 True
# resent firm ARG1 True
# resent group ARG0 True
# resent group ARG1 True
# resent individual ARG0 True
# resent individual ARG1 True
# resent intrusion ARG0 True
# resent intrusion ARG1 True
# resent presence ARG0 True
# resent presence ARG1 True
# resent product ARG0 True
# resent product ARG1 True
# resent transfer ARG0 True
# resent transfer ARG1 True
# resent viewer ARG0 True
# resent viewer ARG1 True
# resent wife ARG0 True
# resent wife ARG1 True
# resent woman ARG0 True
# resent woman ARG1 True
# see analyst ARG0 True
# see analyst ARG1 True
# see drop ARG0 True
# see drop ARG1 True
# see effect ARG0 True
# see effect ARG1 True
# see executive ARG0 True
# see executive ARG1 True
# see face ARG0 True
# see face ARG1 True
# see friend ARG0 True
# see friend ARG1 True
# see investor ARG0 True
# see investor ARG1 True
# see movement ARG0 True
# see movement ARG1 True
# see name ARG0 True
# see name ARG1 True
# see pupil ARG0 True
# see pupil ARG1 True
# see return ARG0 True
# see return ARG1 True
# see viewer ARG0 True
# see viewer ARG1 True
# tell analyst ARG0 True
# tell analyst ARG2 True
# tell chairman ARG0 True
# tell chairman ARG2 True
# tell court ARG0 True
# tell court ARG2 True
# tell department ARG0 True
# tell department ARG2 True
# tell executive ARG0 True
# tell executive ARG2 True
# tell investor ARG0 True
# tell investor ARG2 True
# tell officer ARG0 True
# tell officer ARG2 True
# tell patient ARG0 True
# tell patient ARG2 True
# tell reporter ARG0 True
# tell reporter ARG2 True
# tell senator ARG0 True
# tell senator ARG2 True
# tell therapist ARG0 True
# tell therapist ARG2 True
# False

# %%
data.result_checking('pado_plausibility_pb.txt','Result/lemma_tuple_numerical_pado_plausibility_pb_CodeLlama-13b-Instruct-hf.csv')
# Out:
# 414

# %% [markdown]
# - For Mcrae

# %%
dataset = data.read_data_mcrae('mcrae_agent_patient_more.txt')

for i in range(len(dataset)):
    
    p1 = dataset[i][0]
    a1 = dataset[i][1]
    t1 = dataset[i][2]
    
    IsExist = data.record_exist_other('Result/lemma_tuple_categorical_mcrae_agent_patient_more_CodeLlama-13b-Instruct-hf.csv', p1, a1, t1)
    if not IsExist:
        print(p,predicate,a,argument,t,roleType)
        break

# %%
dataset = data.read_data_mcrae('mcrae_agent_patient_more.txt')
result = data.read_data('Result/lemma_tuple_categorical_mcrae_agent_patient_more_CodeLlama-13b-Instruct-hf.csv')

result.pop(0)

print(len(dataset))
print(len(result)-1)

for i in range(len(dataset)):
    p,a,t= dataset[i][0], dataset[i][1], dataset[i][2]
    p1,a1,t1= result[i][0], result[i][1], result[i][2]
    
    if p != p1 and a != a1 and t != t1:
        print(p,a,t)
        print(p1,a1,t1)
# Out:
# 1444
# 1440

# %%
data.result_checking('mcrae_agent_patient_more.txt','Result/lemma_tuple_numerical_mcrae_agent_patient_more_CodeLlama-13b-Instruct-hf.csv')
